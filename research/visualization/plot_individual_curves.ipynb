# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
transpose_format = 'D:\Work\software\st-bingo\\research\data\processed_data\\vm_1_transpose_bingo_format.txt'
transpose_format
# Out:
# 'D:\\Work\\software\\st-bingo\\research\\data\\processed_data\\vm_1_transpose_bingo_format.txt'

# %%
f = open(transpose_format, 'r')
lines = np.loadtxt(f)
f.close()
lines
# Out:
# array([[2.56015284e-15, 9.92063619e+01, 1.94931035e-15, 0.00000000e+00],
#        [2.57575759e-15, 1.09325529e+02, 2.03055009e-15, 1.00000000e-03],
#        [2.59136235e-15, 1.19444696e+02, 2.11178983e-15, 2.00000000e-03],
#        ...,
#        [3.58018722e-15, 4.63273419e-15, 1.19444696e+02, 2.00000000e-03],
#        [3.37380877e-15, 4.27329810e-15, 1.29563863e+02, 3.00000000e-03],
#        [3.16743033e-15, 3.91386202e-15, 1.39683031e+02, 4.00000000e-03]])

# %%
dataset = [[]]
i = 0
for line in lines:
    if math.isnan(line[0]):
        dataset.append([])
    else:
        dataset[-1].append(line)
dataset = np.array(dataset)
print(dataset)
# Out:
# [[[ 2.56015284e-15  9.92063619e+01  1.94931035e-15  0.00000000e+00]
#   [ 2.57575759e-15  1.09325529e+02  2.03055009e-15  1.00000000e-03]
#   [ 2.59136235e-15  1.19444696e+02  2.11178983e-15  2.00000000e-03]
#   [ 2.60696711e-15  1.29563863e+02  2.19302957e-15  3.00000000e-03]
#   [ 2.62257186e-15  1.39683031e+02  2.27426931e-15  4.00000000e-03]]
#
#  [[ 7.31640346e+01  1.12915617e+02  2.91084235e-16  0.00000000e+00]
#   [ 8.06223289e+01  1.24401731e+02  2.10411130e-17  1.00000000e-03]
#   [ 8.80806232e+01  1.35887845e+02 -2.49002009e-16  2.00000000e-03]
#   [ 9.55389175e+01  1.47373960e+02 -5.19045131e-16  3.00000000e-03]
#   [ 1.02997212e+02  1.58860074e+02 -7.89088253e-16  4.00000000e-03]]
#
#  [[ 8.51233349e+01  1.08948980e+02  5.15803436e-16  0.00000000e+00]
#   [ 9.37860547e+01  1.20024534e+02  4.31146518e-16  1.00000000e-03]
#   [ 1.02448775e+02  1.31100087e+02  3.46489600e-16  2.00000000e-03]
#   [ 1.11111494e+02  1.42175640e+02  2.61832683e-16  3.00000000e-03]
# ...

# %%
plt.plot(dataset[0][:,3])
